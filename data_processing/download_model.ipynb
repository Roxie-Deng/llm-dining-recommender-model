# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

model_name = "google/flan-t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

model.save_pretrained("./model/flan-t5-small")
tokenizer.save_pretrained("./model/flan-t5-small")
# Out:
# ('./model/flan-t5-small\\tokenizer_config.json',
#  './model/flan-t5-small\\special_tokens_map.json',
#  './model/flan-t5-small\\spiece.model',
#  './model/flan-t5-small\\added_tokens.json')

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

model_name = "google/flan-t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

model.save_pretrained("./model/flan-t5-base")
tokenizer.save_pretrained("./model/flan-t5-base")
# Out:
# model.safetensors:  10%|9         | 94.4M/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ('./model/flan-t5-base\\tokenizer_config.json',
#  './model/flan-t5-base\\special_tokens_map.json',
#  './model/flan-t5-base\\spiece.model',
#  './model/flan-t5-base\\added_tokens.json')
